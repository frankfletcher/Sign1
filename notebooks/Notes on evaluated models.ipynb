# %% [markdown]
# RUN_NAME = '20210321-0349 - arch=tf_efficientnet_b4_ns - samples=7500 frozen=1 epochs=48 bs=48 res=380 _data=combined4_with_overflow_all_d' # GREAT 20
#
# ![image.png](attachment:1a9c9c60-3db1-4deb-b77a-3e0a87ab5bf7.png)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# RUN_NAME = '20210323-0353 - arch=tf_efficientnet_b4_ns - samples=7500 frozen=1 epochs=5 bs=48 res=380 _data=combined4_with_overflow_all_d'  # OK 3
#
# ![image.png](attachment:0992a3bc-d006-440a-bf87-f51bdb364276.png)

# %% [markdown]
# RUN_NAME = '20210323-1337 - arch=tf_efficientnet_b4_ns - samples=7500 frozen=1 epochs=10 bs=48 res=380 _data=combined4_with_overflow_all_d'
#
# ![image.png](attachment:95a34603-3b75-4e09-b078-5335982edcb4.png)
