# %%
from datetime import datetime
from fastbook import *
from fastai.vision.all import *
from fastai.vision.widgets import *
import fastai
import gc
import torch


import numpy as np

nimages_in_sample = 1000

WITH_MATRIX = True

# %%
data = 'frank'
path = f'../data/{data}/Training_Set'
path2 = None

# %%
image_files = get_image_files(path)

def get_test_fnames(a):
    return random.sample(image_files, nimages_in_sample)

# %%
# cleaner = None
# test_learn = None
# inputs = None
# preds = None
# interp = None
# targs = None
# decoded = None
# losses = None
# # learn = None
# gc.collect()

# %%
# num = 7
num_epochs = 20
num_pred_runs = 2
# RUN_NAME='20210122-0037 - arch=xresnet50_deep - samples=3000 frozen=1 epochs=40 bs=16 res=360 _data=external'
# RUN_NAME = '20210122-2356 - arch=xresnet50_deep - samples=3000 frozen=1 epochs=40 bs=16 res=360 _data=external'
# RUN_NAME = '20210123-2127 - arch=xresnet50_deep - samples=2000 frozen=1 epochs=22 bs=16 res=360 _data=external'
# RUN_NAME = '20210124-1532 - arch=xresnet50_deep - samples=800 frozen=1 epochs=22 bs=16 res=360 _data=external'
# RUN_NAME = '20210124-2125 - arch=xresnet18 - samples=800 frozen=1 epochs=30 bs=16 res=360 _data=external'
# RUN_NAME = '20210125-1430 - arch=xresnet50 - samples=200 frozen=1 epochs=1 bs=16 res=360 _data=frank'
# RUN_NAME = '20210125-0016 - arch=xresnet50 - samples=800 frozen=1 epochs=20 bs=16 res=360 _data=combined1'
#RUN_NAME = '20210125-1542 - arch=xresnet50 - samples=800 frozen=1 epochs=20 bs=16 res=360 _data=combined1'




RESOLUTION = 360
BATCH_SIZE=32

accd = dict()

for ep in range(1, num_epochs):
    acc_list = []
    print(f'\n\nEPOCH #{ep}')
    
    for pr in range(1, num_pred_runs+1):

        test_learn = load_learner(f'../models/{RUN_NAME}.pkl', cpu=False)
        load_model(f'models/{RUN_NAME}_{ep}.pth', test_learn, opt=Adam, with_opt=False)



        test_db = DataBlock(
            blocks=(ImageBlock, CategoryBlock), 
            get_items=get_test_fnames,
            get_y=parent_label, 
            item_tfms=Resize(RESOLUTION, method='bilinear')) #,
#             item_tfms=CropPad(RESOLUTION, pad_mode='zeros'))
#            ,    batch_tfms=aug_transforms(do_flip=True, size=RESOLUTION, batch=False, max_zoom=1.0, mult=1, pad_mode='zeros'))


        dls = test_db.dataloaders(path, bs=BATCH_SIZE)

        test_dl = dls.test_dl(get_test_fnames(''), with_labels=True)

        with test_learn.no_bar():
            inputs, preds, targs, decoded, losses = test_learn.get_preds(dl=test_dl, with_input=True, with_decoded=True, with_loss=True)

        acc_list.append(accuracy(preds, targs))
        print(f'pred_run: {pr}, accuracy: {round(np.float(100* accuracy(preds, targs)))}%')
    
    accd[ep] = np.mean(acc_list)
    print(f'AVERAGE ACCURACY:      {round(100*np.mean(acc_list))}%')
    
    if WITH_MATRIX:
        interp = ClassificationInterpretation.from_learner(test_learn, dl=test_dl)
        interp.plot_confusion_matrix(figsize=(7,7))
        plt.show()
# Out:
# EPOCH #1
# pred_run: 1, accuracy: 4%
# pred_run: 2, accuracy: 4%
# AVERAGE ACCURACY:      4%
# EPOCH #2
# pred_run: 1, accuracy: 4%
# pred_run: 2, accuracy: 4%
# AVERAGE ACCURACY:      4%
# EPOCH #3
# pred_run: 1, accuracy: 8%
# pred_run: 2, accuracy: 7%
# AVERAGE ACCURACY:      7%
# EPOCH #4
# pred_run: 1, accuracy: 5%
# pred_run: 2, accuracy: 5%
# AVERAGE ACCURACY:      5%
# EPOCH #5
# pred_run: 1, accuracy: 3%
# pred_run: 2, accuracy: 4%
# AVERAGE ACCURACY:      4%
# EPOCH #6
# pred_run: 1, accuracy: 6%
# pred_run: 2, accuracy: 5%
# AVERAGE ACCURACY:      6%
# EPOCH #7
# pred_run: 1, accuracy: 5%
# pred_run: 2, accuracy: 6%
# AVERAGE ACCURACY:      5%
# EPOCH #8
# pred_run: 1, accuracy: 9%
# pred_run: 2, accuracy: 8%
# AVERAGE ACCURACY:      9%
# EPOCH #9
# pred_run: 1, accuracy: 10%
# pred_run: 2, accuracy: 7%
# AVERAGE ACCURACY:      9%
# EPOCH #10
# pred_run: 1, accuracy: 9%
# pred_run: 2, accuracy: 9%
# AVERAGE ACCURACY:      9%
# EPOCH #11
# pred_run: 1, accuracy: 7%
# pred_run: 2, accuracy: 10%
# AVERAGE ACCURACY:      8%
# EPOCH #12
# pred_run: 1, accuracy: 12%
# pred_run: 2, accuracy: 10%
# AVERAGE ACCURACY:      11%
# EPOCH #13
# pred_run: 1, accuracy: 9%
# pred_run: 2, accuracy: 8%
# AVERAGE ACCURACY:      8%
# EPOCH #14
# pred_run: 1, accuracy: 13%
# pred_run: 2, accuracy: 12%
# AVERAGE ACCURACY:      12%
# EPOCH #15
# pred_run: 1, accuracy: 15%
# pred_run: 2, accuracy: 14%
# AVERAGE ACCURACY:      15%
# EPOCH #16
# pred_run: 1, accuracy: 8%
# pred_run: 2, accuracy: 11%
# AVERAGE ACCURACY:      10%
# EPOCH #17
# pred_run: 1, accuracy: 13%
# pred_run: 2, accuracy: 13%
# AVERAGE ACCURACY:      13%
# EPOCH #18
# pred_run: 1, accuracy: 9%
# pred_run: 2, accuracy: 9%
# AVERAGE ACCURACY:      9%
# EPOCH #19
# pred_run: 1, accuracy: 13%
# pred_run: 2, accuracy: 11%
# AVERAGE ACCURACY:      12%

# %%
print('\n   Best Run ')
print('--------------')
print(f'Epoch #:   {max(accd, key=accd.get)}\nAccuracy:  {round(100*max(accd.values()))}%')
# Out:
#    Best Run
# --------------
# Epoch #:   15
# Accuracy:  15%

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ####  Get the Inferrences on the Test Set with the highest score

# %%
# test_learn = load_learner(f'../models/{RUN_NAME}.pkl', cpu=False)
load_model(f'models/{RUN_NAME}_{max(accd, key=accd.get)}.pth', test_learn, opt=Adam, with_opt=False)



test_db = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_test_fnames,
    get_y=parent_label, 
    item_tfms=Resize(RESOLUTION, method='bilinear')) #,
#     item_tfms=CropPad(RESOLUTION, pad_mode='zeros'))
#    ,    batch_tfms=aug_transforms(do_flip=True, size=RESOLUTION, batch=False, max_zoom=1.0, mult=1, pad_mode='zeros'))


dls = test_db.dataloaders(path, bs=BATCH_SIZE)

test_dl = dls.test_dl(get_test_fnames(''), with_labels=True)

with test_learn.no_bar():
    inputs, preds, targs, decoded, losses = test_learn.get_preds(dl=test_dl, with_input=True, with_decoded=True, with_loss=True)
    
print(f'Accuracy: {accuracy(preds, targs)}')
# Out:
# Accuracy: 0.13600000739097595

# %%
interp = ClassificationInterpretation(dl=test_dl, inputs=inputs, preds=preds, targs=targs, decoded=decoded, losses=losses )

# %%
interp.plot_confusion_matrix(figsize=(8,8))

# %%
interp.most_confused()[:10]
# Out:
# [('S', 'H', 40),
#  ('X', 'G', 36),
#  ('U', 'H', 32),
#  ('X', 'H', 31),
#  ('Q', 'H', 25),
#  ('E', 'G', 24),
#  ('L', 'H', 22),
#  ('D', 'G', 21),
#  ('N', 'H', 21),
#  ('T', 'H', 21)]

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Classification Report

# %%
interp.print_classification_report()
# Out:
#               precision    recall  f1-score   support
#
#            A       0.10      0.83      0.18        18
#            B       1.00      0.06      0.11        18
#            C       0.33      0.07      0.11        15
#            D       0.00      0.00      0.00        39
#            E       0.00      0.00      0.00        44
#            F       1.00      0.04      0.08        24
#            G       0.08      0.58      0.14        26
#            H       0.08      0.65      0.13        43
#            I       0.00      0.00      0.00        36
#            K       0.34      0.27      0.30        51
#            L       0.00      0.00      0.00        37
#            M       0.00      0.00      0.00        57
#            N       0.00      0.00      0.00        62
#            O       0.00      0.00      0.00        31
#            P       0.14      0.38      0.20        32
#            Q       0.00      0.00      0.00        37
#            R       0.21      0.09      0.13        32
#            S       0.00      0.00      0.00        65
#            T       0.00      0.00      0.00        55
#            U       0.75      0.07      0.12        90
#            V       0.00      0.00      0.00        35
#            W       0.23      0.87      0.37        31
#            X       0.00      0.00      0.00        83
#            Y       0.59      0.33      0.43        39
#
#     accuracy                           0.14      1000
#    macro avg       0.20      0.18      0.10      1000
# weighted avg       0.18      0.14      0.08      1000
# /home/frank/miniconda3/envs/learn/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/frank/miniconda3/envs/learn/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/frank/miniconda3/envs/learn/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Manual Testing

# %%
tr = 0
fnames = random.sample(get_test_fnames(''), nimages_in_sample)
pred = None
pred_idx = None
probs = None

for i in range(len(fnames)):
    with test_learn.no_bar():
        pred,pred_idx,probs = test_learn.predict(fnames[i])
    
    if pred == str(fnames[i]).split('/')[-2]: tr +=1
print(f'acc: {tr / nimages_in_sample}')
# Out:
# acc: 0.878
